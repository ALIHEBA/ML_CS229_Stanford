# %% [markdown]
# <a href="https://colab.research.google.com/github/ALIHEBA/ML_CS229_Stanford/blob/main/XGBOOST_Customer_Satisfaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score


cust_df = pd.read_csv('/content/drive/MyDrive/Kaggle_Projects/GLM/train.csv')

cust_df['var3'].value_counts()
cust_df['var3'].replace(-999999, 2, inplace = True)
cust_df.drop('ID', axis = 1, inplace = True)

X_feature = cust_df.iloc[: , :-1]
y_label = cust_df.iloc[:,-1]

X_train, X_test, Y_train, Y_test = train_test_split(X_feature, y_label, test_size = 0.2, random_state = 56)
xgb_clf = XGBClassifier(n_estimators = 100, random_state = 156)
xgb_clf.fit(X_train, Y_train, early_stopping_rounds = 100,eval_metric ='auc', eval_set = [(X_test, Y_test)])
# Out:
# [0]	validation_0-auc:0.778639
# Will train until validation_0-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.788469
# [2]	validation_0-auc:0.791285
# [3]	validation_0-auc:0.791188
# [4]	validation_0-auc:0.796183
# [5]	validation_0-auc:0.792246
# [6]	validation_0-auc:0.791629
# [7]	validation_0-auc:0.791542
# [8]	validation_0-auc:0.795324
# [9]	validation_0-auc:0.796558
# [10]	validation_0-auc:0.794108
# [11]	validation_0-auc:0.796533
# [12]	validation_0-auc:0.793329
# [13]	validation_0-auc:0.796734
# [14]	validation_0-auc:0.79848
# [15]	validation_0-auc:0.802954
# [16]	validation_0-auc:0.802905
# [17]	validation_0-auc:0.803133
# [18]	validation_0-auc:0.80321
# [19]	validation_0-auc:0.803273
# [20]	validation_0-auc:0.804895
# [21]	validation_0-auc:0.804797
# [22]	validation_0-auc:0.804845
# [23]	validation_0-auc:0.804888
# [24]	validation_0-auc:0.805779
# [25]	validation_0-auc:0.806764
# [26]	validation_0-auc:0.807057
# [27]	validation_0-auc:0.806572
# ...

# %%
from xgboost import plot_tree
fig, ax = plt.subplots(figsize=(80, 80))
xgboost.plot_tree(xgb_clf, num_trees=4, ax=ax)
plt.show()

# %% [markdown]
# Boosting is One of the ensemble techniques is to combine several Week learner's to improve performance
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# XGBoost stands for Extreme Gradient Boosting.
#
# The algorithm implemented using the boosting technique is representative of Gradient Boost. XGBoost is the implementation of this algorithm in parllel operation.
#
#  Gradient Boost
# It's the leading machine learning library for regression, classification.
#
# ![image.png](data:image/png;base64,...)
